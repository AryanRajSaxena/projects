# %%
import pandas as pd
import numpy as np
import pickle
from PIL import Image
import matplotlib.pyplot as plt

# %%
model_blue = pickle.load(open('/content/Blue.sav', 'rb'))
model_red = pickle.load(open('/content/Red.sav', 'rb'))
model_green = pickle.load(open('/content/Green.sav', 'rb'))

# %%
poly_blue = pickle.load(open('/content/Blue_poly.sav', 'rb'))
poly_red = pickle.load(open('/content/Red_poly.sav', 'rb'))
poly_green = pickle.load(open('/content/Green_poly.sav', 'rb'))

# %%
image = Image.open('/content/test2.jpg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x846>

# %%
image.size
# Out:
# (564, 846)

# %%
for i in range(0,564):
  for j in range(0,846):
    pixels = image.getpixel((i,j))
    pixels = np.array(pixels).reshape(1,3)

    pixels_blue = poly_blue.transform(pixels)
    pixels_green = poly_green.transform(pixels)
    pixels_red = poly_red.transform(pixels)

    blue = model_blue.predict(pixels_blue)
    red = model_red.predict(pixels_green)
    green = model_green.predict(pixels_red)

    new_color = (int(red[0]), int(blue[0]), int(green[0]))
    temp[i,j] = new_color

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x846>

# %%
pixels = image.getpixel((4,5))

# %%
pixels = np.array(pixels).reshape(1,3)

# %%
pixels
# Out:
# array([[67, 67, 67]])

# %%
blue = model_blue.predict(pixels)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
blue[0]
# Out:
# 53
